# %%
import torch
from torch.nn import RMSNorm


rms = RMSNorm(103, 1e-6)
rms.weight = torch.nn.Parameter(torch.linspace(-0.5, 0.7, 103))
x = torch.linspace(-1, 1, 206).reshape(2, 103)

# %%
x.shape
# Out:
# torch.Size([2, 103])

# %%
rms(x)
# Out:
# tensor([[ 0.8618,  0.8333,  0.8052,  0.7776,  0.7502,  0.7233,  0.6968,  0.6707,
#           0.6450,  0.6197,  0.5947,  0.5702,  0.5461,  0.5223,  0.4990,  0.4760,
#           0.4535,  0.4313,  0.4096,  0.3882,  0.3672,  0.3467,  0.3265,  0.3067,
#           0.2873,  0.2683,  0.2497,  0.2315,  0.2137,  0.1963,  0.1793,  0.1627,
#           0.1464,  0.1306,  0.1152,  0.1002,  0.0855,  0.0713,  0.0574,  0.0440,
#           0.0309,  0.0183,  0.0060, -0.0059, -0.0174, -0.0284, -0.0391, -0.0494,
#          -0.0593, -0.0688, -0.0779, -0.0866, -0.0949, -0.1028, -0.1103, -0.1175,
#          -0.1242, -0.1305, -0.1365, -0.1420, -0.1471, -0.1519, -0.1562, -0.1602,
#          -0.1638, -0.1669, -0.1697, -0.1721, -0.1740, -0.1756, -0.1768, -0.1776,
#          -0.1780, -0.1780, -0.1776, -0.1768, -0.1756, -0.1740, -0.1721, -0.1697,
#          -0.1669, -0.1638, -0.1602, -0.1562, -0.1519, -0.1471, -0.1420, -0.1365,
#          -0.1305, -0.1242, -0.1175, -0.1103, -0.1028, -0.0949, -0.0866, -0.0779,
# ...
